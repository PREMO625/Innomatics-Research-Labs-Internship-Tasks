# %% [markdown]
# # Problem 1: Smart Light Controller
#
# ## Problem Statement
# Create a class to control a smart light that can be turned ON or OFF and display its status.
#
# ### 🌍 Real-Time Use
# Smart home automation systems
#
# ### 📥 Sample Input
# - **Light Name**: Bedroom Light
# - **Action**: ON
#
# ### 📤 Expected Output
# Bedroom Light is ON

# %%
class SmartLight:
    def __init__(self, name):
        self.name = name
        self.status = "OFF"

    def set_status(self, action):
        if action.upper() == "ON":
            self.status = "ON"
        elif action.upper() == "OFF":
            self.status = "OFF"
        else:
            print("Invalid Action")

    def display_status(self):
        print(f"{self.name} is {self.status}")

# Sample Usage
light_name = "Bedroom Light"
action = "ON"

my_light = SmartLight(light_name)
my_light.set_status(action)
my_light.display_status()
# Out:
# Bedroom Light is ON

# %% [markdown]
# # Problem 2: Employee ID Card System
#
# ## Problem Statement
# Create a class that stores employee name, ID, and department and displays ID card details.
#
# ### 🌍 Real-Time Use
# Corporate HR systems
#
# ### 📥 Sample Input
# - **Employee Name**: Rahul
# - **Employee ID**: EMP102
# - **Department**: IT
#
# ### 📤 Expected Output
# Employee ID Card
# Name: Rahul
# ID: EMP102
# Department: IT

# %%
class Employee:
    def __init__(self, name, emp_id, department):
        self.name = name
        self.emp_id = emp_id
        self.department = department

    def display_id_card(self):
        print("Employee ID Card")
        print(f"Name: {self.name}")
        print(f"ID: {self.emp_id}")
        print(f"Department: {self.department}")

# Sample Usage
emp_name = "Rahul"
emp_id = "EMP102"
dept = "IT"

emp_card = Employee(emp_name, emp_id, dept)
emp_card.display_id_card()
# Out:
# Employee ID Card
# Name: Rahul
# ID: EMP102
# Department: IT

# %% [markdown]
# # Problem 3: Mobile Contact Record
#
# ## Problem Statement
# Create a class to store contact name and phone number and display contact information.
#
# ### 🌍 Real-Time Use
# Mobile contact applications
#
# ### 📥 Sample Input
# - **Contact Name**: Anita
# - **Phone Number**: 9876543210
#
# ### 📤 Expected Output
# Contact Saved
# Name: Anita
# Phone: 9876543210

# %%
class Contact:
    def __init__(self, name, phone):
        self.name = name
        self.phone = phone

    def display_contact(self):
        print("Contact Saved")
        print(f"Name: {self.name}")
        print(f"Phone: {self.phone}")

# Sample Usage
name = "Anita"
phone = "9876543210"

my_contact = Contact(name, phone)
my_contact.display_contact()
# Out:
# Contact Saved
# Name: Anita
# Phone: 9876543210

# %% [markdown]
# # Problem 4: Product Price Tag Generator
#
# ## Problem Statement
# Create a class that stores product name and price and prints a formatted price tag.
#
# ### 🌍 Real-Time Use
# Retail billing systems
#
# ### 📥 Sample Input
# - **Product Name**: Headphones
# - **Price**: 2499
#
# ### 📤 Expected Output
# Product: Headphones
# Price: ₹2499

# %%
class PriceTag:
    def __init__(self, product_name, price):
        self.product_name = product_name
        self.price = price

    def display_tag(self):
        print(f"Product: {self.product_name}")
        print(f"Price: ₹{self.price}")

# Sample Usage
product = "Headphones"
price = 2499

tag = PriceTag(product, price)
tag.display_tag()
# Out:
# Product: Headphones
# Price: ₹2499

# %% [markdown]
# # Problem 5: Movie Rating Display System
#
# ## Problem Statement
# Create a class that stores movie name and rating and displays movie details.
#
# ### 🌍 Real-Time Use
# Streaming platforms
#
# ### 📥 Sample Input
# - **Movie Name**: Inception
# - **Rating**: 4.8
#
# ### 📤 Expected Output
# Movie: Inception
# Rating: 4.8 / 5

# %%
class MovieRating:
    def __init__(self, movie_name, rating):
        self.movie_name = movie_name
        self.rating = rating

    def display_details(self):
        print(f"Movie: {self.movie_name}")
        print(f"Rating: {self.rating} / 5")

# Sample Usage
movie = "Inception"
rating = 4.8

movie_obj = MovieRating(movie, rating)
movie_obj.display_details()
# Out:
# Movie: Inception
# Rating: 4.8 / 5

# %% [markdown]
# # Problem 6: Delivery Address Manager
#
# ## Problem Statement
# Create a class that stores customer name and delivery address and prints delivery details.
#
# ### 🌍 Real-Time Use
# Courier and logistics platforms
#
# ### 📥 Sample Input
# - **Customer Name**: Suman
# - **Address**: Hyderabad
#
# ### 📤 Expected Output
# Delivery Details
# Customer: Suman
# Address: Hyderabad

# %%
class DeliveryManager:
    def __init__(self, customer_name, address):
        self.customer_name = customer_name
        self.address = address

    def display_delivery_details(self):
        print("Delivery Details")
        print(f"Customer: {self.customer_name}")
        print(f"Address: {self.address}")

# Sample Usage
customer = "Suman"
addr = "Hyderabad"

delivery = DeliveryManager(customer, addr)
delivery.display_delivery_details()
# Out:
# Delivery Details
# Customer: Suman
# Address: Hyderabad
